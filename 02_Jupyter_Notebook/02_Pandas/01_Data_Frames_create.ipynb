# %%
import pandas as pd

data = {"Name":["john","Peter","Lisa"],
       "Age":[25,28,31],
       "Salary":[30000,45000,25000]}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Salary
# 0   john   25   30000
# 1  Peter   28   45000
# 2   Lisa   31   25000

# %%
# Reading CSV file from same directort
data = pd.read_csv("customers.csv")
print(data)
# Out:
#            id               name      segment           state  \
# 0    CG-12520        Claire Gute     Consumer        Kentucky
# 1    DV-13045    Darrin Van Huff    Corporate      California
# 2    SO-20335     Sean O'Donnell     Consumer         Florida
# 3    BH-11710    Brosina Hoffman     Consumer      California
# 4    AA-10480       Andrew Allen     Consumer  North Carolina
# ..        ...                ...          ...             ...
# 788  CJ-11875       Carl Jackson    Corporate    Pennsylvania
# 789  RS-19870         Roy Skaria  Home Office            Iowa
# 790  SC-20845         Sung Chung     Consumer        Illinois
# 791  RE-19405    Ricardo Emerson     Consumer            Ohio
# 792  SM-20905  Susan MacKendrick     Consumer            Ohio
#
#                   city
# 0            Henderson
# 1          Los Angeles
# 2      Fort Lauderdale
# 3          Los Angeles
# 4              Concord
# ..                 ...
# 788       Philadelphia
# 789         Burlington
# ...

# %%
# Reading csv data from any directory use Froward slash rather than backslash
data = pd.read_csv("C:/Users/Rahul Kumr/Documents/Github/Data-Science-Learning/02_Jupyter_Notebook/02_Pandas/customers.csv")
print(data)
# Out:
#            id               name      segment           state  \
# 0    CG-12520        Claire Gute     Consumer        Kentucky
# 1    DV-13045    Darrin Van Huff    Corporate      California
# 2    SO-20335     Sean O'Donnell     Consumer         Florida
# 3    BH-11710    Brosina Hoffman     Consumer      California
# 4    AA-10480       Andrew Allen     Consumer  North Carolina
# ..        ...                ...          ...             ...
# 788  CJ-11875       Carl Jackson    Corporate    Pennsylvania
# 789  RS-19870         Roy Skaria  Home Office            Iowa
# 790  SC-20845         Sung Chung     Consumer        Illinois
# 791  RE-19405    Ricardo Emerson     Consumer            Ohio
# 792  SM-20905  Susan MacKendrick     Consumer            Ohio
#
#                   city
# 0            Henderson
# 1          Los Angeles
# 2      Fort Lauderdale
# 3          Los Angeles
# 4              Concord
# ..                 ...
# 788       Philadelphia
# 789         Burlington
# ...

# %%
# Read excel file (for excel file pyexcel is required)
data = pd.read_excel("customers.xlsx")
print(data)
# Out:
#            id               name      segment           state  \
# 0    CG-12520        Claire Gute     Consumer        Kentucky
# 1    DV-13045    Darrin Van Huff    Corporate      California
# 2    SO-20335     Sean O'Donnell     Consumer         Florida
# 3    BH-11710    Brosina Hoffman     Consumer      California
# 4    AA-10480       Andrew Allen     Consumer  North Carolina
# ..        ...                ...          ...             ...
# 788  CJ-11875       Carl Jackson    Corporate    Pennsylvania
# 789  RS-19870         Roy Skaria  Home Office            Iowa
# 790  SC-20845         Sung Chung     Consumer        Illinois
# 791  RE-19405    Ricardo Emerson     Consumer            Ohio
# 792  SM-20905  Susan MacKendrick     Consumer            Ohio
#
#                   city
# 0            Henderson
# 1          Los Angeles
# 2      Fort Lauderdale
# 3          Los Angeles
# 4              Concord
# ..                 ...
# 788       Philadelphia
# 789         Burlington
# ...
